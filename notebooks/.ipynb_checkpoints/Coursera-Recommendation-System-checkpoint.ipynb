# %% [markdown]
# # Importing Libraries

# %%
# import pandas for dataframe
import pandas as pd
# import numpy for transformations
import numpy as np
# visulization librarie
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## 1. Data Gathering and Data Overview

# %%
df1 = pd.read_csv('../data/Coursera.csv')  # Go one level up and access data.csv
df1.head()  # Display first few rows
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                   Course Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...
# 2  chemistry  physics  Solar Energy  film  lambda...
# 3  accounts receivable  dupont analysis  analysis...
# 4  Data Analysis  select (sql)  database manageme...

# %%
# Make a copy of the data
df = df1.copy()

# %%
# Check Shape of the data
df.shape
# Out:
# (3522, 7)

# %%
df.info()  # Check for columns datatype and more about the size of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Course Name         3522 non-null   object
#  1   University          3522 non-null   object
#  2   Difficulty Level    3522 non-null   object
#  3   Course Rating       3522 non-null   object
#  4   Course URL          3522 non-null   object
#  5   Course Description  3522 non-null   object
#  6   Skills              3522 non-null   object
# dtypes: object(7)
# memory usage: 192.7+ KB

# %%
# show the columns name
df.columns
# Out:
# Index(['Course Name', 'University', 'Difficulty Level', 'Course Rating',
#        'Course URL', 'Course Description', 'Skills'],
#       dtype='object')

# %%
# Check for missing values
df.isna().sum()
# Out:
# Course Name           0
# University            0
# Difficulty Level      0
# Course Rating         0
# Course URL            0
# Course Description    0
# Skills                0
# dtype: int64

# %% [markdown]
# **Conclusion**
#
# - In the data there are total 7 columns
# - And there is no missing data

# %% [markdown]
# ## 2. Data Cleaning

# %%
# Check for the Duplicates rows
df.duplicated().sum()
# Out:
# 98

# %%
df[df.duplicated()].sample(10)
# Out:
#                                             Course Name  \
# 3469  Google Cloud Platform Fundamentals: Core Infra...
# 3061                                  Regression Models
# 1791                     Data Visualization with Python
# 932         Network Security & Database Vulnerabilities
# 1169                             Symmetric Cryptography
# 1888     Exploratory Data Analysis for Machine Learning
# 582        Aromatherapy: Clinical Use of Essential Oils
# 2401                    Supervised Learning: Regression
# 688                               Data Science Capstone
# 751                              Managing an Agile Team
#
#                          University Difficulty Level Course Rating  \
# 3469                   Google Cloud       Conversant           4.7
# 3061       Johns Hopkins University         Beginner           4.3
# 1791                            IBM         Beginner           4.4
# 932                             IBM         Beginner           4.6
# 1169  University of Colorado System         Advanced           4.5
# 1888                            IBM     Intermediate           4.8
# 582         University of Minnesota     Intermediate           4.8
# 2401                            IBM         Advanced             5
# 688        Johns Hopkins University         Advanced           4.3
# 751          University of Virginia         Beginner           4.7
#
#                                              Course URL  \
# 3469    https://www.coursera.org/learn/gcp-fundamentals
# 3061   https://www.coursera.org/learn/regression-models
# 1791  https://www.coursera.org/learn/python-for-data...
# 932   https://www.coursera.org/learn/network-securit...
# 1169    https://www.coursera.org/learn/symmetric-crypto
# 1888  https://www.coursera.org/learn/ibm-exploratory...
# 582   https://www.coursera.org/learn/aromatherapy-cl...
# 2401  https://www.coursera.org/learn/supervised-lear...
# 688   https://www.coursera.org/learn/data-science-pr...
# 751   https://www.coursera.org/learn/uva-darden-agil...
#
#                                      Course Description  \
# 3469  This course introduces you to important concep...
# 3061  Linear models, as their name implies, relates ...
# 1791  "A picture is worth a thousand words". We are ...
# 932   This course gives you the background needed to...
# 1169  Welcome to Symmetric Cryptography!   Symmetric...
# 1888  This first course in the IBM Machine Learning ...
# 582   This course provides an overview of essential ...
# 2401  This course introduces you to one of the main ...
# 688   The capstone project class will allow students...
# 751   While agile has become the de facto standard f...
#
#                                                  Skills
# 3469  Google Cloud Platform  Big Data  Cloud Infrast...
# 3061  linearity  linear model  modeling  Regression ...
# 1791  Chart  Python Programming  Choropleth Map  ana...
# 932   Databases  database security  data security  s...
# 1169  ruby on rails  cipher  symmetric-key algorithm...
# 1888  Bayesian  nonparametric statistics  Feature En...
# 582   medicine  cosmetics  ayurveda  oil  anxiety  a...
# 2401  Regression  Early Stopping  Validation Set  Ma...
# 688   Data Analysis  Machine Learning  Human Learnin...
# 751   openfabrics alliance  kanban  scrum (software ...

# %%
# Drop the duplicate rows from the data
df.drop_duplicates(keep='first', inplace=True)

# %%
# Shape of the data
df.shape
# Out:
# (3424, 7)

# %%
# Function to remove extra space from text
def remove_space(text):
    if isinstance(text,str):
        text = text.strip().lower()
        return text
    return text

# %%
# now apply the remove_space function to the all the text columns 
df['Course Name'] = df['Course Name'].apply(clean_text)
df['Course Rating'] = df['Course Rating'].apply(clean_text)
df['University'] = df['University'].apply(clean_text)
df['Difficulty Level'] = df['Difficulty Level'].apply(clean_text)
df['Course URL'] = df['Course URL'].apply(clean_text)
df['Course Description'] = df['Course Description'].apply(clean_text)
df['Skills'] = df['Skills'].apply(clean_text)

# %%
# check random 10 rows
df.sample(10)
# Out:
#                                             Course Name  \
# 1387                        quantitative model checking
# 2841                 communicating data science results
# 2260             introduction to molecular spectroscopy
# 2701             process mining: data science in action
# 1337  containerize a full-stack nodejs application i...
# 3403                    introduction to web development
# 2880                explore stock prices with spark sql
# 3043  the sustainable development goals � a global, ...
# 803   understanding your google cloud platform (gcp)...
# 1155                      digitalisation in aeronautics
#
#                                 University Difficulty Level Course Rating  \
# 1387                           eit digital         advanced           4.1
# 2841              university of washington         advanced           3.6
# 2260              university of manchester         beginner           4.7
# 2701    eindhoven university of technology         beginner           4.8
# 1337              coursera project network         beginner           4.8
# 3403       university of california, davis       conversant           4.6
# 2880              coursera project network         beginner           4.4
# 3043              university of copenhagen         beginner           4.8
# 803                           google cloud         advanced           4.6
# 1155  technische universit�t m�nchen (tum)         advanced             5
#
#                                              Course URL  \
# 1387  https://www.coursera.org/learn/quantitative-mo...
# 2841        https://www.coursera.org/learn/data-results
# 2260        https://www.coursera.org/learn/spectroscopy
# 2701      https://www.coursera.org/learn/process-mining
# 1337  https://www.coursera.org/learn/containerize-fu...
# 3403     https://www.coursera.org/learn/web-development
# 2880  https://www.coursera.org/learn/data-exploratio...
# 3043  https://www.coursera.org/learn/global-sustaina...
# 803   https://www.coursera.org/learn/gcp-cost-manage...
# 1155         https://www.coursera.org/learn/aeronautics
#
#                                      Course Description  \
# 1387  the integration of ict (information and commun...
# 2841  important note: the second assignment in this ...
# 2260  the course introduces the three key spectrosco...
# 2701  process mining is the missing link between mod...
# 1337  in this 1-hour long project-based course on in...
# 3403  this course is designed to start you on a path...
# 2880  in this 1-hour long project-based course, you ...
# 3043  in 2015, the un launched the 17 sustainable de...
# 803   understanding your google cloud platform (gcp)...
# 1155  the instructors of the online course "digitali...
#
#                                                  Skills
# 1387  modulo operation  null coalescing operator  da...
# 2841  communication  recursively enumerable set  gen...
# 2260  interpretation  chemical engineering  analysis...
# 2701  process modeling  business process  process mi...
# 1337  node.js  databases  application development  l...
# 3403  web  web design  html5  web development  web p...
# 2880  analysis  sql  stock  statistical analysis  sa...
# 3043  climate change  problem solving  awareness  th...
# 803   google cloud platform  cloud computing  plant ...
# 1155  nastran  unmanned aerial vehicle  traffic simu...

# %%
# renaming the columns name
df.rename(columns={'Course Name' : 'Name', 
                   'Course Rating' : 'Rating',
                  'Course URL' : 'URL',
                  'Course Description' : 'Description'},inplace=True)

# %%
df.head()
# Out:
#                                                 Name  \
# 0  write a feature length screenplay for film or ...
# 1  business strategy: business model canvas analy...
# 2                      silicon thin film solar cells
# 3                               finance for managers
# 4       retrieve data using single-table sql queries
#
#                   University Difficulty Level Rating  \
# 0  michigan state university         beginner    4.8
# 1   coursera project network         beginner    4.8
# 2        �cole polytechnique         advanced    4.1
# 3       iese business school     intermediate    4.8
# 4   coursera project network         beginner    4.6
#
#                                                  URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                          Description  \
# 0  write a full length feature film script  in th...
# 1  by the end of this guided project, you will be...
# 2  this course consists of a general presentation...
# 3  when it comes to numbers, there is always more...
# 4  in this course you�ll learn how to effectively...
#
#                                               Skills
# 0  drama  comedy  peering  screenwriting  film  d...
# 1  finance  business plan  persona (user experien...
# 2  chemistry  physics  solar energy  film  lambda...
# 3  accounts receivable  dupont analysis  analysis...
# 4  data analysis  select (sql)  database manageme...

# %%
# Change the datatype of the rating column
